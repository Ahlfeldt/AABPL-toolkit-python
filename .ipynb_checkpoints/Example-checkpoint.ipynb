# %% [markdown]
# ### Install package from console or within script

# %%
# install package into your environment through your console via
# pip install ABRSQOL
# or install it from this script:
import subprocess, sys
subprocess.check_call([sys.executable, "-m", "pip", "install", 'aabpl', "--upgrade"])
# Out:
# 0

# %% [markdown]
# ### set up working directory and folders

# %%
subprocess.check_call([sys.executable, "-m", "pip", "install", 'concave_hull', "--upgrade"])
# Out:
# 0

# %%
import os
# Create output folders if they don't exist
working_directory = "./" # specify your folder path here C:/User/YourName/YourFolder
output_data_folder = os.path.join(working_directory, "output_data/")
output_gis_folder = os.path.join(working_directory, "output_gis/")
output_maps_folder = os.path.join(working_directory, "output_maps/")
temp_folder = os.path.join(working_directory, "temp")
os.makedirs(output_data_folder, exist_ok=True)
os.makedirs(output_gis_folder, exist_ok=True)
os.makedirs(output_maps_folder, exist_ok=True)
os.makedirs(temp_folder, exist_ok=True)

# %% [markdown]
# ### Import packages

# %%
# unique_reg_id_combs_in_raster_cells {(0,): 
# ...
# [(10, 7), (11, 7)], (1001, 9010, 19026): 
# [(10, 8), (10, 9), (10, 10), (11, 8), (11, 9), (11, 10), (11, 11)], (8009, 9010): 
# ...

# %%
# check_tree: {
#     'check': <function create_radius_check.<locals>.<lambda> at 0x0000020F7DAFFC40>, 
#         True: 9010, 
#         False: {'check': <function create_radius_check.<locals>.<lambda> at 0x0000020F0067DDA0>, 
#                 True: 19026, 
#                 False: 1001}}

# %%
from pandas import read_csv
from aabpl.main import radius_search, detect_cluster_pts, detect_cluster_cells
from aabpl.testing.test_performance import analyze_func_perf, func_timer_dict
path_to_your_csv ='Z:/Algorithm/cbsa_sample_data/plants_16980.txt'
crs_of_your_csv =  "EPSG:4326"
pts = read_csv(path_to_your_csv, sep=",", header=None)[:50000]
pts.columns = ["eid", "employment", "industry", "lat", "lon", "moved"]
grid = radius_search(
    pts=pts,
    crs=crs_of_your_csv,
    r=750,
    c='employment',
    exclude_pt_itself=True,
    nest_depth=0,
    # plot_cell_reg_assign={},
    # plot_offset_checks={},
    # plot_offset_regions={},
    # plot_offset_raster={},
)
# Out:
# Please note that the package 'aabpl' is under active development. Your currently using version 0.1.27

# %%
from aabpl.valid_area import infer_sample_area_poly_from_pts
poly=infer_sample_area_poly_from_pts(
    pts=pts,
    grid=None,
    hull_type='concave',
    concavity=0.2,
    buffer=0.01
)
poly
# Out:
# q 2.0
# q 2.0
# <POLYGON ((-88.339 41.904, -88.328 41.928, -88.34 41.957, -88.33 42.017, -88...>

# %%
from pandas import read_csv
from aabpl.main import radius_search, detect_cluster_pts, detect_cluster_cells
from aabpl.testing.test_performance import analyze_func_perf, func_timer_dict
path_to_your_csv ='../../cbsa_sample_data/plants_16980.txt'
crs_of_your_csv =  "EPSG:4326"
pts = read_csv(path_to_your_csv, sep=",", header=None)[:30000]
pts.columns = ["eid", "employment", "industry", "lat","lon","moved"]
grid = detect_cluster_cells(
    pts=pts,
    crs=crs_of_your_csv,
    r=750,
    c='employment',
    exclude_pt_itself=True,
    valid_area='concave',
    queen_contingency=1,
    centroid_dist_threshold=25000,
    border_dist_threshold=10000,
    min_cluster_share_after_contingency=0.05,
    k_th_percentile=99.5,
    n_random_points=100000,
    make_convex=True,
    random_seed=0,
    nest_depth=0,
    plot_distribution={},
    # plot_cluster_points={},
    # plot_pt_disk={},
    # plot_cell_reg_assign={},
    # plot_offset_checks={},
    # plot_offset_regions={},
    # plot_offset_raster={},
)
# Out:
# Please note that the package 'aabpl' is under active development. Your currently using version 0.1.27
# plot_offset_checks None plot_offset_regions None plot_offset_raster None
# 11plot_offset_checks None plot_offset_regions None plot_offset_raster None

# %%
path_to_your_csv ='../../cbsa_sample_data/plants_16980.txt'
crs_of_your_csv =  "EPSG:4326"
pts = read_csv(path_to_your_csv, sep=",", header=None)[:50000]
pts.columns = ["eid", "employment", "industry", "lat","lon","moved"]
grid = radius_search(
    pts=pts,
    r=750,
    crs='EPSG:4326',
    c=['employment'],
    silent = True,
)
perf_analysis = analyze_func_perf(plot=True)
perf_analysis['grp_df'].groupby('func_name')['process_time'].sum()

# %%
path_to_your_csv = 'input_data/prime_points_weighted_79.txt'
crs_of_your_csv =  "EPSG:4326"
pts = read_csv(path_to_your_csv, sep=",", header=None)
pts.columns = ["eid", "employment", "industry", "lat","lon","moved"]

# %%
input_folder = '../DebuggingArena/GA/plants/'
for f in os.listdir(input_folder)[:1]:
    path_to_your_csv = input_folder+f
    path_to_your_csv ='../DebuggingArena/GA/plants/prime_points_weighted_4.txt'
    crs_of_your_csv =  "EPSG:4326"
    try:
        pts = read_csv(path_to_your_csv, sep=",", header=None)
    except:
        print("Can't read data from "+path_to_your_csv)
        continue
    pts.columns = ["eid", "employment", "industry", "lat","lon","moved"]
    grid = detect_cluster_cells(
        pts=pts,
        crs=crs_of_your_csv,
        r=750,
        c='employment',
        exclude_pt_itself=True,
        queen_contingency=1,
        centroid_dist_threshold=25000,
        border_dist_threshold=10000,
        min_cluster_share_after_contingency=0.05,
        k_th_percentile=99.5,
        n_random_points=100000,
        make_convex=True,
        random_seed=0,
    )
    # save files as needed
    # save only only clusters including their geometry, aggregate values, area and id
    # grid.save_cell_clusters(filename=output_gis_folder+f+'grid_clusters', file_format='shp')
    df_clus = grid.save_cell_clusters(filename=output_data_folder+f+'grid_clusters', file_format='csv')
    # save sparse grid including cells only those cells that at least contain one point
    # df_sparse_grid = grid.save_sparse_grid(filename=output_gis_folder+f+'sparse_grid', file_format='shp')
    # df_sparse_grid = grid.save_sparse_grid(filename=output_data_folder+f+'sparse_grid', file_format='csv')
    # save full grid including cells that have no points in them (through many empty cells this will occuppy unecessary disk space)
    # df_full_grid = grid.save_full_grid(filename=output_gis_folder+f+'full_grid', file_format='shp')
    # df_full_grid = grid.save_full_grid(filename=output_data_folder+f+'full_grid', file_format='csv')
    fig = grid.plot.clusters(output_maps_folder+f+"_emp_99_5.jpg", close_plot=True)
    # pts.to_csv(output_data_folder+'pts_w_clusters.csv')

# %%
grid.plot.rand_dist(output_maps_folder+"rand_dist")

# %%
fig = grid.plot.clusters(output_maps_folder+'test.jpg')

# %%
df = grid.create_sparse_grid_df()
df.plot('cluster_id')

# %% [markdown]
# ## Save DataFrames with radius sums and clusters
# Using all the save options below is most likely excessive. saving the shapefile for save_grid_clusters and save_sparse_grid is most likely sufficient

# %%
# save files as needed
# save only only clusters including their geometry, aggregate values, area and id
df_clusters = grid.save_cell_clusters(filename=output_gis_folder+'clusters', file_format='shp')
df_clusters = grid.save_cell_clusters(filename=output_data_folder+'clusters', file_format='csv')

# save sparse grid including cells only those cells that at least contain one point
df_sparse_grid = grid.save_sparse_grid(filename=output_gis_folder+'sparse_grid', file_format='shp')
df_sparse_grid = grid.save_sparse_grid(filename=output_data_folder+'sparse_grid', file_format='csv')

# save full grid including cells that have no points in them (through many empty cells this will occuppy unecessary disk space)
# df_full_grid = grid.save_full_grid(filename=output_gis_folder+'full_grid', file_format='shp')
# df_full_grid = grid.save_full_grid(filename=output_data_folder+'full_grid', file_format='csv')

pts.to_csv(output_data_folder+'pts_df_w_clusters.csv')

# %% [markdown]
# ## Create Plots

# %%
df_sparse_grid.plot('cluster_id')

# %%
grid.plot.cell_aggregates(output_maps_folder+'aggregates')

# %%
grid.plot.cluster_vars()

# %%
grid.plot.cluster_pts(filename=output_maps_folder+'employment_cluster_pts')

# %%
grid.plot.rand_dist(filename=output_maps_folder+'rand_dist_employment')

# %% [markdown]
# ## For development use only

# %%
grid = radius_search(
    pts=pts,
    r=750,
    crs='EPSG:4326',
    c=['employment']
)

# %%
grid = radius_search(
    pts=pts,
    r=750,
    crs='EPSG:4326',
    c=['employment'],
    silent = True,
)
perf_analysis = analyze_func_perf(plot=True)
perf_analysis['grp_df'].groupby('func_name')['process_time'].sum()

# %%
# only calculate sums (no clustering)
grid = radius_search(
    pts=pts, 
    r=750, 
    c=['employment'],
    plot_radius_sums={'figsize':(20,30), 'cmap': 'viridis'},
    silent=True
)

# %% [markdown]
# # some plots on internal processes

# %%
grid = detect_cluster_cells(
    pts=pts,
    crs='EPSG:4326',
    r=750,
    c=['employment'],
    exclude_pt_itself=True,
    centroid_dist_threshold=25000,
    border_dist_threshold=10000,
    k_th_percentile=99.97,
    n_random_points=int(1e5),
    make_convex=True,
    random_seed=0,
    plot_distribution={},
    plot_radius_sums={},
    plot_cluster_points={},
    plot_pt_disk={},
    plot_cell_reg_assign={},
    plot_offset_checks={},
    plot_offset_regions={},
    plot_offset_raster={},
    silent = True,
)
